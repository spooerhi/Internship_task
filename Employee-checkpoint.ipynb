# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">📚 Importing Libraries</p>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">📥 LOADING DATASET</p>

# %%
data = pd.read_csv(r"C:\Users\PC\Desktop\MCA\Data Analytics\DataSets\employe dataset.csv")

# %%
data
# Out:
#        emp_id  age        Dept location education  job_level  rating  awards  \
# 0      HR8270   28          HR   Suburb        PG          5       2       1
# 1    TECH1860   50  Technology   Suburb        PG          3       5       2
# 2    TECH6390   43  Technology   Suburb        UG          4       1       2
# 3     SAL6191   44       Sales     City        PG          2       3       0
# 4      HR6734   33          HR     City        UG          2       1       5
# ..        ...  ...         ...      ...       ...        ...     ...     ...
# 495    HR5330   49          HR   Suburb        PG          2       5       6
# 496  TECH9010   24  Technology   Suburb        UG          2       4       2
# 497   MKT7801   34   Marketing     City        PG          1       3       2
# 498  TECH5846   26  Technology     City        UG          2       1       1
# 499  TECH7731   26  Technology     City        UG          3       4       3
#
# ...

# %% [markdown]
# #### head()

# %%
data.head()
# Out:
#      emp_id  age        Dept location education  job_level  rating  awards  \
# 0    HR8270   28          HR   Suburb        PG          5       2       1
# 1  TECH1860   50  Technology   Suburb        PG          3       5       2
# 2  TECH6390   43  Technology   Suburb        UG          4       1       2
# 3   SAL6191   44       Sales     City        PG          2       3       0
# 4    HR6734   33          HR     City        UG          2       1       5
#
#    certifications  salary  satisfied gender  Years_of_ Experience
# 0               0   86750          1      m                     7
# 1               1   42419          0      m                    10
# 2               0   65715          0      f                     0
# 3               0   29805          1      f                     8
# 4               0   29805          1      m                     2

# %% [markdown]
# #### info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   emp_id                500 non-null    object
#  1   age                   500 non-null    int64
#  2   Dept                  500 non-null    object
#  3   location              500 non-null    object
#  4   education             500 non-null    object
#  5   job_level             500 non-null    int64
#  6   rating                500 non-null    int64
#  7   awards                500 non-null    int64
#  8   certifications        500 non-null    int64
#  9   salary                500 non-null    int64
#  10  satisfied             500 non-null    int64
#  11  gender                500 non-null    object
#  12  Years_of_ Experience  500 non-null    int64
# dtypes: int64(8), object(5)
# memory usage: 50.9+ KB

# %% [markdown]
# #### shape()

# %%
data.shape
# Out:
# (500, 13)

# %% [markdown]
# #### describe()

# %%
data.describe()
# Out:
#               age   job_level      rating      awards  certifications  \
# count  500.000000  500.000000  500.000000  500.000000      500.000000
# mean    38.610000    3.032000    3.072000    4.538000        0.496000
# std      9.438648    1.423738    1.425089    2.853215        0.500485
# min     23.000000    1.000000    1.000000    0.000000        0.000000
# 25%     30.000000    2.000000    2.000000    2.000000        0.000000
# 50%     39.000000    3.000000    3.000000    5.000000        0.000000
# 75%     47.000000    4.000000    4.000000    7.000000        1.000000
# max     54.000000    5.000000    5.000000    9.000000        1.000000
#
#              salary   satisfied  Years_of_ Experience
# count    500.000000  500.000000            500.000000
# mean   50416.056000    0.526000              7.040000
# std    23671.392661    0.499824              6.458004
# min    24076.000000    0.000000              0.000000
# 25%    29805.000000    0.000000              3.000000
# ...

# %% [markdown]
# ### *observation* :
#  ### Age-:
#
#  * ### .the average age of employee is 38
#  * ### .minimum age is 23 and maximum is 54
#
# ### salary-:
#
# * ### .the avg salary of employee is 50416 and max is 86750.
# * ### .50% of employee getting salary under 42419.
#
# ### Years_of_ Experience-:
#
# * ### .avg exp of employee is 7 years
# * ### .max Experience employee is 40 years
# * ### .75% of employee are having 9 years Experience

# %% [markdown]
# #### isnull()

# %%
data.isnull().sum()
# Out:
# emp_id                  0
# age                     0
# Dept                    0
# location                0
# education               0
# job_level               0
# rating                  0
# awards                  0
# certifications          0
# salary                  0
# satisfied               0
# gender                  0
# Years_of_ Experience    0
# dtype: int64

# %% [markdown]
# ### *observation* : In this dataset there is no null value paresent.

# %% [markdown]
# #### dtypes

# %%
data.dtypes
# Out:
# emp_id                  object
# age                      int64
# Dept                    object
# location                object
# education               object
# job_level                int64
# rating                   int64
# awards                   int64
# certifications           int64
# salary                   int64
# satisfied                int64
# gender                  object
# Years_of_ Experience     int64
# dtype: object

# %% [markdown]
# #### *observation* : In this dataset  5 object and 8 numarical attributes are there.

# %% [markdown]
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Q1. What is the average salary of employees by department?</p>

# %%
data.groupby(['Dept']).mean().salary
# Out:
# Dept
# HR            49629.764151
# Marketing     50122.663158
# Purchasing    54555.743119
# Sales         53493.076087
# Technology    44057.969388
# Name: salary, dtype: float64

# %% [markdown]
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Q2. Which department has the highest number of employees?</p>

# %%
data['Dept'].value_counts().head(1)
# Out:
# Purchasing    109
# Name: Dept, dtype: int64

# %% [markdown]
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Q3. What is the distribution of gender in the company?</p>

# %%
 data['gender'].value_counts()
# Out:
# m    270
# f    230
# Name: gender, dtype: int64

# %%
sns.set(rc={'figure.figsize':(14,8)})
sns.displot(data=data, x="gender")

# %% [markdown]
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Q4. Is there a correlation between years of experience and salary?</p>

# %%
sns.set(rc={'figure.figsize':(14,8)})
sns.scatterplot(x = "Years_of_ Experience", y = "salary", data = data )
# Out:
# <AxesSubplot:xlabel='Years_of_ Experience', ylabel='salary'>

# %%
sns.set(rc={'figure.figsize':(14,8)})
sns.lmplot(x = "Years_of_ Experience", y = "salary", data=data)

# %% [markdown]
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Q5. Which department has the highest average salary?</p>

# %%
data.groupby(['Dept']).mean()['salary'].sort_values().tail(1)
# Out:
# Dept
# Purchasing    54555.743119
# Name: salary, dtype: float64

# %% [markdown]
# # <p style="padding:10px;background-color:#D3D3D3;margin:0;color:black;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">Exploratory Data Analysis</p>

# %% [markdown]
#  ### Univariate Analysis

# %%
# CountPlot

sns.set(rc={'figure.figsize':(14,8)})
sns.countplot(x=data['location'],data=data,palette ='bright')
# Out:
# <AxesSubplot:xlabel='location', ylabel='count'>

# %% [markdown]
# ###  *obsevation* :  As you can see in this graph employee are more from city .

# %%
# countplot
 
sns.set(rc={'figure.figsize':(14,8)})
sns.countplot(x=data["education"])
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %% [markdown]
# ### *observation* : As you can see in above graph most of the employee education is PG.

# %%
#  which department has highest rating?
data['rating'].value_counts()
# Out:
# 4    113
# 5    106
# 2     99
# 1     95
# 3     87
# Name: rating, dtype: int64

# %%
# pie Chart
sns.set(rc={'figure.figsize':(14,8)})
data['rating'].value_counts().plot(kind="pie" , autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='rating'>

# %% [markdown]
# ### *observation* : As you can see in this pie chart employee getting rating of 4 is more.

# %%
sns.set(rc={'figure.figsize':(14,8)})
sns.displot(data=data, x="salary",kde = True)

# %% [markdown]
# ### *observation* : From the above graph the more employee getting salary count of 30000-40000.

# %% [markdown]
# ### Bivariate Analysis

# %%
df=data[['job_level','rating','awards','certifications','salary','satisfied','age','Years_of_ Experience']]

# %%
# heatmap

sns.set(rc={'figure.figsize':(14,8)})
sns.heatmap(df.corr(),annot=True, fmt=".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### *observation* : By seeing this heatmap there is no correation in between those attributes.

# %%
# barplot

sns.set(rc={'figure.figsize':(14,8)})
sns.barplot(data=data, x="Dept", y="salary", hue="certifications")
# Out:
# <AxesSubplot:xlabel='Dept', ylabel='salary'>

# %% [markdown]
# ### *observation* :  By seeing above graph the employee working in purchasing department with certification getting more salary.

# %%
# boxplot
sns.set(rc={'figure.figsize':(14,8)})
sns.boxplot(data=data, x='Dept', y='salary')
# Out:
# <AxesSubplot:xlabel='Dept', ylabel='salary'>

# %%
#lineplot
sns.set(rc={'figure.figsize':(14,8)})
sns.lineplot(data=data, x="Years_of_ Experience", y="salary",hue="gender")
# Out:
# <AxesSubplot:xlabel='Years_of_ Experience', ylabel='salary'>

# %% [markdown]
# ### *observation* : As u can see when years of experience is increasing the employee salary is also increasing.
# ### In that female are getting more salary as compared to male.
